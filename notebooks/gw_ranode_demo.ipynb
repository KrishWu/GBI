# %% [markdown]
# # R-Anode Gravitational Wave Demo
#
# Minimal end-to-end walkthrough for training and evaluating the Residual ANODE (R-Anode) pipeline on toy gravitational wave strain data.

# %% [markdown]
# This notebook keeps only the components required to:
#
# 1. Generate toy gravitational wave background and signal events
# 2. Preprocess and split the data into sidebands (control) and signal regions
# 3. Train the background density estimator (normalizing flow)
# 4. Train the residual signal flow with a fixed signal fraction hypothesis
# 5. Evaluate the learned anomaly score on a held-out sample
#
# All heavy Luigi/Law orchestration is skipped so the core R-Anode logic can be inspected interactively.

# %%
import os
import sys
import copy
import json
import pathlib
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# ensure project root (with 'config/' and 'src/') is on sys.path
project_root = pathlib.Path.cwd().resolve()
if not (project_root / "config").exists():
    candidate = project_root.parent
    if (candidate / "config").exists():
        project_root = candidate
if (project_root / "config").exists() and str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print(f"Using project root: {project_root}")

from config import configs
from src.data_prep.gw_processing import process_gw_backgrounds, process_gw_signals, gw_background_split
from src.data_prep.utils import preprocess_params_fit, logit_transform, standardize, inverse_transform
from src.models.model_B import DensityEstimator, anode
from src.models.model_S import flows_model_RQS, r_anode_mass_joint_untransformed
from scipy.stats import rv_histogram

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
if device.type == "mps":
    torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float32)

torch.manual_seed(42)

# %%
SIGNAL_AMPLITUDE = 120.0  # tweak amplitude to study sensitivity

raw_bkg = process_gw_backgrounds()
raw_sig = process_gw_signals(amplitude=SIGNAL_AMPLITUDE)

def combine_signal_with_background(background: np.ndarray, signal: np.ndarray, scale: float = 1.0) -> np.ndarray:
    if background.shape != signal.shape:
        raise ValueError("Signal and background must share identical shape")
    combined = background.copy()
    if not np.allclose(background[:, 0], signal[:, 0], atol=1e-8):
        raise ValueError("Time grids for signal and background do not align")
    combined[:, 1] = background[:, 1] + scale * signal[:, 1]
    combined[:, 2] = background[:, 2] + scale * signal[:, 2]
    combined[:, 3] = combined[:, 1] + combined[:, 2]
    combined[:, 4] = combined[:, 1] - combined[:, 2]
    combined[:, -1] = 1.0
    return combined

combined_signal_raw = combine_signal_with_background(raw_bkg, raw_sig)
assert np.allclose(combined_signal_raw[:, 0], raw_bkg[:, 0])
assert np.allclose(combined_signal_raw[:, 1] - raw_bkg[:, 1], raw_sig[:, 1])
assert np.allclose(combined_signal_raw[:, 2] - raw_bkg[:, 2], raw_sig[:, 2])
assert np.allclose(combined_signal_raw[:, 3], combined_signal_raw[:, 1] + combined_signal_raw[:, 2])
assert np.allclose(combined_signal_raw[:, 4], combined_signal_raw[:, 1] - combined_signal_raw[:, 2])
print("Verified: signal is added sample-wise to the background")

print(f"Background shape: {raw_bkg.shape}")
print(f"Signal template shape: {raw_sig.shape}")
print(f"Signal+background combined shape: {combined_signal_raw.shape}")
print("Columns: [time, H, L, H+L, H-L, label]")
# Out:
# Verified: signal is added sample-wise to the background
# Background shape: (300, 6)
# Signal template shape: (300, 6)
# Signal+background combined shape: (300, 6)
# Columns: [time, H, L, H+L, H-L, label]

# %%
# --- split background into signal/control regions and fit preprocessing ---
SR_bkg_raw, CR_bkg_raw = gw_background_split(raw_bkg, resample_seed=42)
# I am instead basing the preprocessing params on the signal region. IMPORTANT NOTE for KRISH
# pre_params = preprocess_params_fit(CR_bkg_raw)
SR_sig_raw, CR_sig_raw = gw_background_split(combined_signal_raw, resample_seed=42)
pre_params = preprocess_params_fit(SR_sig_raw)
feature_min = pre_params["min"]
feature_max = pre_params["max"]
feature_range = feature_max - feature_min
buffer = np.maximum(feature_range * 0.1, 1e-3)
pre_params["min"] = feature_min - buffer
pre_params["max"] = feature_max + buffer
print("Pre_params:", pre_params)

def transform_with_params(data, params, clip_eps=1e-6):
    feature_min = params["min"]
    feature_max = params["max"]
    feature_mean = params["mean"]
    feature_std = params["std"]

    denom = feature_max - feature_min
    denom = np.where(denom == 0, 1e-6, denom)
    x = data[:, 1:-1]
    x_norm = (x - feature_min) / denom
    x_norm = np.clip(x_norm, clip_eps, 1 - clip_eps)
    logit = np.log(x_norm / (1 - x_norm))
    mask = np.isfinite(logit).all(axis=1)

    transformed = np.hstack([data[:, 0:1], logit, data[:, -1:]])[mask]
    transformed[:, 1:-1] = standardize(transformed[:, 1:-1], feature_mean, feature_std)
    return transformed, data[mask]

CR_processed, CR_aligned_raw = transform_with_params(CR_bkg_raw, pre_params)
SR_bkg_processed, SR_bkg_aligned_raw = transform_with_params(SR_bkg_raw, pre_params)
SR_sig_processed, SR_sig_aligned_raw = transform_with_params(SR_sig_raw, pre_params)

print(f"Control-region processed shape: {CR_processed.shape}")
print(f"Signal-region background shape: {SR_bkg_processed.shape}")
print(f"Signal-region injected signal shape: {SR_sig_processed.shape}")

# Build background mass/time PDF for later mixing
hist_counts, hist_bins = np.histogram(SR_bkg_aligned_raw[:, 0], bins=40, density=True)
mass_density = rv_histogram((hist_counts, hist_bins))

plt.clf()
# plt.scatter(SR_bkg_raw[:, 0], SR_bkg_raw[:, 1], label='Signal Region Background Time Distribution')
# plt.scatter(CR_bkg_raw[:, 0], CR_bkg_raw[:, 1], label='Control Region Background Time Distribution')
plt.scatter(SR_bkg_processed[:, 0], SR_bkg_processed[:, 1], label='Processed Signal Region Background Time Distribution')
plt.scatter(SR_sig_processed[:, 0], SR_sig_processed[:, 1], label='Processed Signal+Background Time Distribution')
# plt.scatter(CR_sig_raw[:, 0], CR_sig_raw[:, 1], label='Signal Region Raw Signal+Background Time Distribution')
plt.scatter(CR_processed[:, 0], CR_processed[:, 1], label='Processed Control Region Background Time Distribution')
plt.xlabel('Time (s)')
plt.ylabel('Strain')
plt.legend()
plt.title('Gravitational Wave Data Processing')
plt.show()
# Out:
# GW Background split: Inner=150, Outer=150
# GW Background split: Inner=150, Outer=150
# Pre_params: {'min': array([-3.06451559, -2.74923999, -3.86177193, -3.86559586]), 'max': array([2.80668132, 2.68843517, 3.97472177, 4.19058328]), 'mean': array([ 0.11172711,  0.00654411, -0.11560925, -0.12594138]), 'std': array([0.92513397, 0.90703172, 0.90351279, 0.91915508])}
# Control-region processed shape: (150, 6)
# Signal-region background shape: (150, 6)
# Signal-region injected signal shape: (150, 6)

# %%
plt.clf()
plt.hist(SR_bkg_processed[:, 1], bins=40, alpha=0.5, label='Signal Region Background Time Histogram')
plt.hist(CR_processed[:, 1], bins=40, alpha=0.5, label='Control Region Background Time Histogram')
plt.hist(SR_sig_processed[:, 1], bins=40, alpha=0.5, label='Signal+Background Time Histogram')
plt.xlabel('Strain')
plt.ylabel('Density')
plt.legend()
plt.title('Strain Distribution Comparison')
plt.show()

# %%
# --- train the background normalizing flow on CR data ---
CR_train, CR_val = train_test_split(CR_processed, test_size=0.25, random_state=42, shuffle=True)

train_tensor = torch.from_numpy(CR_train.astype("float32")).to(device)
val_tensor = torch.from_numpy(CR_val.astype("float32")).to(device)

train_loader = DataLoader(TensorDataset(train_tensor), batch_size=512, shuffle=True)
val_loader = DataLoader(TensorDataset(val_tensor), batch_size=1024, shuffle=False)

config_path = project_root / "src" / "models" / "DE_MAF_model.yml"
model_B = DensityEstimator(str(config_path), eval_mode=False, device=device)

bkg_train_losses = []
bkg_val_losses = []
best_state = None
best_val = float("inf")
patience = 0
PATIENCE_LIMIT = 5
EPOCHS_BKG = 200

for epoch in range(1, EPOCHS_BKG + 1):
    train_loss = anode(model_B.model, train_loader, model_B.optimizer, params=None, device=device, mode="train")
    val_loss = anode(model_B.model, val_loader, model_B.optimizer, params=None, device=device, mode="val")
    bkg_train_losses.append(float(train_loss))
    bkg_val_losses.append(float(val_loss))
    print(f"[Bkg] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
    if val_loss < best_val - 1e-4:
        best_val = val_loss
        best_state = copy.deepcopy({k: v.cpu() for k, v in model_B.model.state_dict().items()})
        patience = 0
    else:
        patience += 1
        if patience >= PATIENCE_LIMIT:
            print("Stopping early (background model)")
            break

if best_state is not None:
    model_B.model.load_state_dict(best_state)
model_B.model.to(device)
model_B.model.eval()
# Out:
# DensityEstimator has 274800 parameters
# setting batch norm layers to eval mode
# [Bkg] Epoch 01 | train: 123.9948 | val: 118.7617
# setting batch norm layers to eval mode
# [Bkg] Epoch 02 | train: 116.7608 | val: 109.9638
# setting batch norm layers to eval mode
# [Bkg] Epoch 03 | train: 108.0700 | val: 104.5792
# setting batch norm layers to eval mode
# [Bkg] Epoch 04 | train: 102.8055 | val: 96.8294
# setting batch norm layers to eval mode
# [Bkg] Epoch 05 | train: 95.1082 | val: 91.0767
# setting batch norm layers to eval mode
# [Bkg] Epoch 06 | train: 89.4721 | val: 83.6853
# setting batch norm layers to eval mode
# [Bkg] Epoch 07 | train: 82.1783 | val: 79.2398
# setting batch norm layers to eval mode
# [Bkg] Epoch 08 | train: 77.6967 | val: 76.7362
# setting batch norm layers to eval mode
# [Bkg] Epoch 09 | train: 75.1516 | val: 73.3032
# setting batch norm layers to eval mode
# [Bkg] Epoch 10 | train: 71.7819 | val: 67.2685
# setting batch norm layers to eval mode
# [Bkg] Epoch 11 | train: 65.8872 | val: 66.0359
# setting batch norm layers to eval mode
# [Bkg] Epoch 12 | train: 64.7159 | val: 62.6567
# setting batch norm layers to eval mode
# [Bkg] Epoch 13 | train: 61.2596 | val: 58.9611
# setting batch norm layers to eval mode
# [Bkg] Epoch 14 | train: 57.6688 | val: 57.5892
# setting batch norm layers to eval mode
# [Bkg] Epoch 15 | train: 56.2615 | val: 54.9193
# setting batch norm layers to eval mode
# [Bkg] Epoch 16 | train: 53.5942 | val: 51.2560
# setting batch norm layers to eval mode
# [Bkg] Epoch 17 | train: 49.9088 | val: 49.9895
# setting batch norm layers to eval mode
# [Bkg] Epoch 18 | train: 48.6548 | val: 46.0904
# setting batch norm layers to eval mode
# [Bkg] Epoch 19 | train: 44.8243 | val: 44.0341
# setting batch norm layers to eval mode
# [Bkg] Epoch 20 | train: 42.8638 | val: 37.7313
# setting batch norm layers to eval mode
# [Bkg] Epoch 21 | train: 36.6580 | val: 40.6085
# setting batch norm layers to eval mode
# [Bkg] Epoch 22 | train: 39.8271 | val: 39.1769
# setting batch norm layers to eval mode
# [Bkg] Epoch 23 | train: 38.5058 | val: 39.7206
# setting batch norm layers to eval mode
# [Bkg] Epoch 24 | train: 39.1083 | val: 37.8374
# setting batch norm layers to eval mode
# [Bkg] Epoch 25 | train: 37.2339 | val: 35.3923
# setting batch norm layers to eval mode
# [Bkg] Epoch 26 | train: 34.7756 | val: 33.4393
# setting batch norm layers to eval mode
# [Bkg] Epoch 27 | train: 32.7585 | val: 32.2345
# setting batch norm layers to eval mode
# [Bkg] Epoch 28 | train: 31.4933 | val: 32.1681
# setting batch norm layers to eval mode
# [Bkg] Epoch 29 | train: 31.5097 | val: 30.1854
# setting batch norm layers to eval mode
# [Bkg] Epoch 30 | train: 29.6969 | val: 26.9398
# setting batch norm layers to eval mode
# [Bkg] Epoch 31 | train: 26.6948 | val: 25.5509
# setting batch norm layers to eval mode
# [Bkg] Epoch 32 | train: 25.0080 | val: 24.0870
# setting batch norm layers to eval mode
# [Bkg] Epoch 33 | train: 23.3220 | val: 22.5443
# setting batch norm layers to eval mode
# [Bkg] Epoch 34 | train: 22.5721 | val: 20.5838
# setting batch norm layers to eval mode
# [Bkg] Epoch 35 | train: 20.7180 | val: 19.0303
# setting batch norm layers to eval mode
# [Bkg] Epoch 36 | train: 19.1265 | val: 19.2840
# setting batch norm layers to eval mode
# [Bkg] Epoch 37 | train: 19.1114 | val: 19.0581
# setting batch norm layers to eval mode
# [Bkg] Epoch 38 | train: 18.7134 | val: 18.4380
# setting batch norm layers to eval mode
# [Bkg] Epoch 39 | train: 18.0328 | val: 17.0200
# setting batch norm layers to eval mode
# [Bkg] Epoch 40 | train: 16.5291 | val: 15.3523
# setting batch norm layers to eval mode
# [Bkg] Epoch 41 | train: 14.9391 | val: 13.9103
# setting batch norm layers to eval mode
# [Bkg] Epoch 42 | train: 13.2623 | val: 13.1973
# setting batch norm layers to eval mode
# [Bkg] Epoch 43 | train: 12.7346 | val: 12.9238
# setting batch norm layers to eval mode
# [Bkg] Epoch 44 | train: 12.8006 | val: 12.5771
# setting batch norm layers to eval mode
# [Bkg] Epoch 45 | train: 12.5175 | val: 10.9471
# setting batch norm layers to eval mode
# [Bkg] Epoch 46 | train: 11.0318 | val: 10.0652
# setting batch norm layers to eval mode
# [Bkg] Epoch 47 | train: 10.0215 | val: 9.7646
# setting batch norm layers to eval mode
# [Bkg] Epoch 48 | train: 9.4194 | val: 9.5544
# setting batch norm layers to eval mode
# [Bkg] Epoch 49 | train: 8.9429 | val: 8.5513
# setting batch norm layers to eval mode
# [Bkg] Epoch 50 | train: 7.8617 | val: 7.5768
# setting batch norm layers to eval mode
# [Bkg] Epoch 51 | train: 7.0520 | val: 7.1009
# setting batch norm layers to eval mode
# [Bkg] Epoch 52 | train: 6.4910 | val: 6.5270
# setting batch norm layers to eval mode
# [Bkg] Epoch 53 | train: 6.4266 | val: 6.1306
# setting batch norm layers to eval mode
# [Bkg] Epoch 54 | train: 5.8722 | val: 7.3046
# setting batch norm layers to eval mode
# [Bkg] Epoch 55 | train: 7.4468 | val: 7.1942
# setting batch norm layers to eval mode
# [Bkg] Epoch 56 | train: 7.2583 | val: 6.1307
# setting batch norm layers to eval mode
# [Bkg] Epoch 57 | train: 5.9674 | val: 5.8449
# setting batch norm layers to eval mode
# [Bkg] Epoch 58 | train: 6.0555 | val: 6.0614
# setting batch norm layers to eval mode
# [Bkg] Epoch 59 | train: 6.1902 | val: 5.8988
# setting batch norm layers to eval mode
# [Bkg] Epoch 60 | train: 5.9907 | val: 5.2205
# setting batch norm layers to eval mode
# [Bkg] Epoch 61 | train: 5.1237 | val: 5.3892
# setting batch norm layers to eval mode
# [Bkg] Epoch 62 | train: 5.3873 | val: 4.8578
# setting batch norm layers to eval mode
# [Bkg] Epoch 63 | train: 4.7006 | val: 4.4159
# setting batch norm layers to eval mode
# [Bkg] Epoch 64 | train: 4.5645 | val: 4.2310
# setting batch norm layers to eval mode
# [Bkg] Epoch 65 | train: 4.4415 | val: 3.9372
# setting batch norm layers to eval mode
# [Bkg] Epoch 66 | train: 4.0274 | val: 3.7993
# setting batch norm layers to eval mode
# [Bkg] Epoch 67 | train: 3.4616 | val: 3.7219
# setting batch norm layers to eval mode
# [Bkg] Epoch 68 | train: 3.3834 | val: 3.2391
# setting batch norm layers to eval mode
# [Bkg] Epoch 69 | train: 3.0200 | val: 2.8881
# setting batch norm layers to eval mode
# [Bkg] Epoch 70 | train: 2.7421 | val: 2.5475
# setting batch norm layers to eval mode
# [Bkg] Epoch 71 | train: 2.5474 | val: 2.1378
# setting batch norm layers to eval mode
# [Bkg] Epoch 72 | train: 2.1648 | val: 1.8620
# setting batch norm layers to eval mode
# [Bkg] Epoch 73 | train: 1.7857 | val: 1.9027
# setting batch norm layers to eval mode
# [Bkg] Epoch 74 | train: 1.6722 | val: 1.6212
# setting batch norm layers to eval mode
# [Bkg] Epoch 75 | train: 1.3715 | val: 0.9384
# setting batch norm layers to eval mode
# [Bkg] Epoch 76 | train: 0.8487 | val: 0.5903
# setting batch norm layers to eval mode
# [Bkg] Epoch 77 | train: 0.5884 | val: 0.8777
# setting batch norm layers to eval mode
# [Bkg] Epoch 78 | train: 0.1973 | val: 0.5861
# setting batch norm layers to eval mode
# [Bkg] Epoch 79 | train: 0.0239 | val: 1.1239
# setting batch norm layers to eval mode
# [Bkg] Epoch 80 | train: 0.4300 | val: 1.0140
# setting batch norm layers to eval mode
# [Bkg] Epoch 81 | train: 0.4607 | val: 1.1885
# setting batch norm layers to eval mode
# [Bkg] Epoch 82 | train: 0.2504 | val: 0.3120
# setting batch norm layers to eval mode
# [Bkg] Epoch 83 | train: -0.7323 | val: 0.5486
# setting batch norm layers to eval mode
# [Bkg] Epoch 84 | train: 0.6577 | val: 0.1639
# setting batch norm layers to eval mode
# [Bkg] Epoch 85 | train: 0.1356 | val: -0.0449
# setting batch norm layers to eval mode
# [Bkg] Epoch 86 | train: -0.5717 | val: 0.1517
# setting batch norm layers to eval mode
# [Bkg] Epoch 87 | train: -0.2014 | val: -0.1470
# setting batch norm layers to eval mode
# [Bkg] Epoch 88 | train: -0.4958 | val: -1.0103
# setting batch norm layers to eval mode
# [Bkg] Epoch 89 | train: -1.2517 | val: -0.5925
# setting batch norm layers to eval mode
# [Bkg] Epoch 90 | train: -0.9276 | val: -0.8721
# setting batch norm layers to eval mode
# [Bkg] Epoch 91 | train: -1.1134 | val: -1.3942
# setting batch norm layers to eval mode
# [Bkg] Epoch 92 | train: -1.4657 | val: -1.3365
# setting batch norm layers to eval mode
# [Bkg] Epoch 93 | train: -1.5118 | val: -0.9550
# setting batch norm layers to eval mode
# [Bkg] Epoch 94 | train: -1.4920 | val: -0.9412
# setting batch norm layers to eval mode
# [Bkg] Epoch 95 | train: -0.9866 | val: -1.0538
# setting batch norm layers to eval mode
# [Bkg] Epoch 96 | train: -1.3711 | val: -0.6222
# Stopping early (background model)
# FlowSequential(
#   (0): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (1): BatchNormFlow()
#   (2): Reverse()
#   (3): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (4): BatchNormFlow()
#   (5): Reverse()
#   (6): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (7): BatchNormFlow()
#   (8): Reverse()
#   (9): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (10): BatchNormFlow()
#   (11): Reverse()
#   (12): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (13): BatchNormFlow()
#   (14): Reverse()
#   (15): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (16): BatchNormFlow()
#   (17): Reverse()
#   (18): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (19): BatchNormFlow()
#   (20): Reverse()
#   (21): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (22): BatchNormFlow()
#   (23): Reverse()
#   (24): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (25): BatchNormFlow()
#   (26): Reverse()
#   (27): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (28): BatchNormFlow()
#   (29): Reverse()
#   (30): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (31): BatchNormFlow()
#   (32): Reverse()
#   (33): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (34): BatchNormFlow()
#   (35): Reverse()
#   (36): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (37): BatchNormFlow()
#   (38): Reverse()
#   (39): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (40): BatchNormFlow()
#   (41): Reverse()
#   (42): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (43): BatchNormFlow()
#   (44): Reverse()
# )

# %%
# --- prepare signal-region datasets & background log probabilities ---
SR_combined_processed = np.vstack([SR_bkg_processed, SR_sig_processed])
SR_combined_raw = np.vstack([SR_bkg_aligned_raw, SR_sig_aligned_raw])

indices = np.arange(len(SR_combined_processed))
train_idx, test_idx = train_test_split(
    indices,
    test_size=0.2,
    random_state=1337,
    stratify=SR_combined_processed[:, -1],
)

SR_train_all = SR_combined_processed[train_idx]
SR_train_raw_all = SR_combined_raw[train_idx]
SR_test = SR_combined_processed[test_idx]
SR_test_raw = SR_combined_raw[test_idx]

with torch.no_grad():
    train_tensor_all = torch.from_numpy(SR_train_all.astype("float32")).to(device)
    log_B_train_all = model_B.model.log_probs(
        inputs=train_tensor_all[:, 1:-1],
        cond_inputs=train_tensor_all[:, 0:1],
    ).cpu().numpy()

    test_tensor = torch.from_numpy(SR_test.astype("float32")).to(device)
    log_B_test = model_B.model.log_probs(
        inputs=test_tensor[:, 1:-1],
        cond_inputs=test_tensor[:, 0:1],
    ).cpu().numpy()

mass_pdf_train_all = mass_density.pdf(SR_train_raw_all[:, 0])
mass_pdf_test = mass_density.pdf(SR_test_raw[:, 0])

# split train into (train, val)
inner_indices = np.arange(len(SR_train_all))
train_inner_idx, val_inner_idx = train_test_split(
    inner_indices,
    test_size=0.2,
    random_state=2024,
    stratify=SR_train_all[:, -1],
)

SR_train = SR_train_all[train_inner_idx]
SR_val = SR_train_all[val_inner_idx]
SR_train_raw = SR_train_raw_all[train_inner_idx]
SR_val_raw = SR_train_raw_all[val_inner_idx]

log_B_train = log_B_train_all[train_inner_idx]
log_B_val = log_B_train_all[val_inner_idx]

mass_pdf_train = mass_pdf_train_all[train_inner_idx]
mass_pdf_val = mass_pdf_train_all[val_inner_idx]

center_time = 0.5 * (configs.SR_MIN + configs.SR_MAX)
def shift_time(data):
    shifted = data.copy()
    shifted[:, 0] -= center_time
    return shifted

SR_train_shifted = shift_time(SR_train)
SR_val_shifted = shift_time(SR_val)
SR_test_shifted = shift_time(SR_test)
SR_sig_shifted = shift_time(SR_sig_processed)

signal_fraction = float(SR_train[:, -1].mean())
print(f"Training signal fraction w ≈ {signal_fraction:.4f}")
# Out:
# Training signal fraction w ≈ 0.5000

# %%
# --- train the residual signal flow ---
train_dataset = TensorDataset(
    torch.from_numpy(SR_train_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_train.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_train.astype("float32")).to(device),
)
val_dataset = TensorDataset(
    torch.from_numpy(SR_val_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_val.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_val.astype("float32")).to(device),
)

train_loader_S = DataLoader(train_dataset, batch_size=256, shuffle=True)
val_loader_S = DataLoader(val_dataset, batch_size=512, shuffle=False)

model_S = flows_model_RQS(
    num_layers=4,
    num_features=4,
    num_blocks=2,
    hidden_features=64,
    device=device,
    context_features=1,
)

optimizer_S = torch.optim.AdamW(model_S.parameters(), lr=3e-4)
scheduler_S = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer_S, T_0=10, T_mult=2)

sig_train_losses = []
sig_val_losses = []
best_state_S = None
best_val_S = float("inf")
patience_S = 0
PATIENCE_LIMIT_S = 8
EPOCHS_SIG = 200

for epoch in range(1, EPOCHS_SIG + 1):
    train_loss = r_anode_mass_joint_untransformed(
        model_S=model_S,
        w=signal_fraction,
        optimizer=optimizer_S,
        data_loader=train_loader_S,
        device=device,
        mode="train",
        scheduler=scheduler_S,
    )
    val_loss = r_anode_mass_joint_untransformed(
        model_S=model_S,
        w=signal_fraction,
        optimizer=optimizer_S,
        data_loader=val_loader_S,
        device=device,
        mode="val",
    )
    sig_train_losses.append(float(train_loss))
    sig_val_losses.append(float(val_loss))
    print(f"[Signal] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
    if val_loss < best_val_S - 1e-4:
        best_val_S = val_loss
        best_state_S = copy.deepcopy({k: v.cpu() for k, v in model_S.state_dict().items()})
        patience_S = 0
    else:
        patience_S += 1
        if patience_S >= PATIENCE_LIMIT_S:
            print("Stopping early (signal model)")
            break
    scheduler_S.step()

if best_state_S is not None:
    model_S.load_state_dict(best_state_S)
model_S.to(device)
model_S.eval()
# Out:
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 01 | train: 6.6130 | val: 6.2996
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 02 | train: 6.3691 | val: 6.1492
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 03 | train: 6.3190 | val: 6.1589
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 04 | train: 6.0985 | val: 6.1530
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 05 | train: 6.2020 | val: 6.1451
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 06 | train: 6.1609 | val: 6.1083
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 07 | train: 6.0543 | val: 6.0658
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 08 | train: 6.0103 | val: 6.0224
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 09 | train: 5.8577 | val: 5.9797
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 10 | train: 5.9316 | val: 5.9405
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 11 | train: 5.7606 | val: 5.9001
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 12 | train: 5.7470 | val: 5.8684
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 13 | train: 5.6719 | val: 5.8422
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 14 | train: 5.7562 | val: 5.8182
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 15 | train: 5.7311 | val: 5.7971
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 16 | train: 5.7308 | val: 5.7300
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 17 | train: 5.7297 | val: 5.6704
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 18 | train: 5.6549 | val: 5.6105
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 19 | train: 5.5103 | val: 5.5503
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 20 | train: 5.5273 | val: 5.4851
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 21 | train: 5.3893 | val: 5.4232
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 22 | train: 5.4422 | val: 5.3633
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 23 | train: 5.3514 | val: 5.3040
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 24 | train: 5.3479 | val: 5.2516
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 25 | train: 5.2382 | val: 5.2025
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 26 | train: 5.2758 | val: 5.1618
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 27 | train: 5.1050 | val: 5.1224
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 28 | train: 5.1036 | val: 5.0874
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 29 | train: 5.2491 | val: 5.0501
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 30 | train: 5.1647 | val: 5.0211
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 31 | train: 5.1117 | val: 4.9933
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 32 | train: 5.0878 | val: 4.9694
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 33 | train: 5.0846 | val: 4.9436
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 34 | train: 4.9785 | val: 4.9236
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 35 | train: 5.0479 | val: 4.8997
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 36 | train: 5.0070 | val: 4.8352
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 37 | train: 5.0084 | val: 4.7745
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 38 | train: 5.0220 | val: 4.7103
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 39 | train: 5.0306 | val: 4.6429
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 40 | train: 4.8207 | val: 4.5733
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 41 | train: 5.0303 | val: 4.5084
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 42 | train: 4.8333 | val: 4.4428
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 43 | train: 4.7668 | val: 4.3772
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 44 | train: 4.8059 | val: 4.3105
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 45 | train: 4.6690 | val: 4.2538
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 46 | train: 4.4800 | val: 4.1955
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 47 | train: 4.6233 | val: 4.1379
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 48 | train: 4.5161 | val: 4.0826
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 49 | train: 4.5522 | val: 4.0279
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 50 | train: 4.5052 | val: 3.9723
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 51 | train: 4.6000 | val: 3.9292
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 52 | train: 4.5242 | val: 3.8834
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 53 | train: 4.5144 | val: 3.8518
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 54 | train: 4.5881 | val: 3.8216
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 55 | train: 4.3604 | val: 3.7894
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 56 | train: 4.2929 | val: 3.7675
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 57 | train: 4.4197 | val: 3.7476
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 58 | train: 4.3429 | val: 3.7285
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 59 | train: 4.2868 | val: 3.7159
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 60 | train: 4.2488 | val: 3.7007
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 61 | train: 4.3867 | val: 3.6885
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 62 | train: 4.2681 | val: 3.6761
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 63 | train: 4.2708 | val: 3.6688
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 64 | train: 4.3699 | val: 3.6654
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 65 | train: 4.5961 | val: 3.6612
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 66 | train: 4.2249 | val: 3.6523
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 67 | train: 4.1832 | val: 3.6419
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 68 | train: 4.2951 | val: 3.6356
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 69 | train: 4.3644 | val: 3.6267
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 70 | train: 4.4252 | val: 3.6226
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 71 | train: 4.4175 | val: 3.6195
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 72 | train: 4.4106 | val: 3.6179
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 73 | train: 4.2923 | val: 3.6161
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 74 | train: 4.3101 | val: 3.6100
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 75 | train: 4.2360 | val: 3.6086
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 76 | train: 4.2729 | val: 3.5758
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 77 | train: 4.3347 | val: 3.5537
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 78 | train: 4.2222 | val: 3.5445
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 79 | train: 4.2466 | val: 3.5307
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 80 | train: 4.1071 | val: 3.5174
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 81 | train: 4.1058 | val: 3.5027
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 82 | train: 4.0346 | val: 3.4694
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 83 | train: 3.9408 | val: 3.4378
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 84 | train: 3.9055 | val: 3.4096
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 85 | train: 4.0533 | val: 3.3813
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 86 | train: 3.9480 | val: 3.3593
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 87 | train: 4.0539 | val: 3.3393
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 88 | train: 3.8617 | val: 3.3314
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 89 | train: 3.8407 | val: 3.3318
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 90 | train: 3.7969 | val: 3.3261
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 91 | train: 3.8155 | val: 3.3309
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 92 | train: 3.7870 | val: 3.3226
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 93 | train: 3.9798 | val: 3.3096
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 94 | train: 3.8739 | val: 3.2855
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 95 | train: 3.6156 | val: 3.2471
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 96 | train: 3.6440 | val: 3.2062
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 97 | train: 3.7164 | val: 3.1798
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 98 | train: 3.6975 | val: 3.1424
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 99 | train: 3.6331 | val: 3.1138
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 100 | train: 3.6275 | val: 3.0916
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 101 | train: 3.4797 | val: 3.0791
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 102 | train: 3.6062 | val: 3.0593
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 103 | train: 3.4094 | val: 3.0431
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 104 | train: 3.3178 | val: 3.0290
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 105 | train: 3.4576 | val: 3.0222
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 106 | train: 3.4806 | val: 3.0165
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 107 | train: 3.5520 | val: 3.0063
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 108 | train: 3.5134 | val: 2.9946
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 109 | train: 3.5264 | val: 2.9818
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 110 | train: 3.3313 | val: 2.9647
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 111 | train: 3.5102 | val: 2.9514
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 112 | train: 3.3572 | val: 2.9344
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 113 | train: 3.4803 | val: 2.9224
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 114 | train: 3.5211 | val: 2.9158
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 115 | train: 3.4332 | val: 2.9086
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 116 | train: 3.4312 | val: 2.9040
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 117 | train: 3.3465 | val: 2.9022
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 118 | train: 3.2744 | val: 2.9041
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 119 | train: 3.4164 | val: 2.9023
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 120 | train: 3.3742 | val: 2.8980
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 121 | train: 3.3071 | val: 2.8959
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 122 | train: 3.1733 | val: 2.8895
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 123 | train: 3.1900 | val: 2.8801
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 124 | train: 3.1773 | val: 2.8672
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 125 | train: 3.2055 | val: 2.8528
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 126 | train: 3.1997 | val: 2.8435
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 127 | train: 3.2889 | val: 2.8402
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 128 | train: 3.3891 | val: 2.8357
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 129 | train: 3.2522 | val: 2.8279
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 130 | train: 3.3093 | val: 2.8233
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 131 | train: 3.2237 | val: 2.8214
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 132 | train: 3.1784 | val: 2.8179
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 133 | train: 3.1301 | val: 2.8142
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 134 | train: 3.2310 | val: 2.8137
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 135 | train: 3.2652 | val: 2.8127
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 136 | train: 3.1639 | val: 2.8103
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 137 | train: 3.2019 | val: 2.8107
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 138 | train: 3.2340 | val: 2.8128
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 139 | train: 3.2386 | val: 2.8145
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 140 | train: 3.2324 | val: 2.8135
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 141 | train: 3.2685 | val: 2.8095
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 142 | train: 3.2082 | val: 2.8104
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 143 | train: 3.2679 | val: 2.8052
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 144 | train: 3.1390 | val: 2.8091
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 145 | train: 3.3104 | val: 2.8095
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 146 | train: 3.1310 | val: 2.8100
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 147 | train: 3.1997 | val: 2.8109
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 148 | train: 3.2657 | val: 2.8112
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 149 | train: 3.1217 | val: 2.8065
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 150 | train: 3.2990 | val: 2.8081
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 151 | train: 3.2778 | val: 2.8058
# Stopping early (signal model)
# Flow(
#   (_transform): CompositeTransform(
#     (_transforms): ModuleList(
#       (0): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (1): RandomPermutation()
#       (2): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (3): RandomPermutation()
#       (4): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (5): RandomPermutation()
#       (6): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (7): RandomPermutation()
#     )
#   )
#   (_distribution): StandardNormal()
#   (_embedding_net): Identity()
# )

# %%
# Plot training curves for background and signal models
fig, ax = plt.subplots(1, 2, figsize=(12, 4), sharex=True)
ax[0].plot(bkg_train_losses, label="Train")
ax[0].plot(bkg_val_losses, label="Validation")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].set_title("Background Flow Training")
ax[0].legend()

ax[1].plot(sig_train_losses, label="Train")
ax[1].plot(sig_val_losses, label="Validation")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")
ax[1].set_title("Signal Flow Training")
ax[1].legend()
plt.tight_layout()
plt.show()

# %%
# --- evaluate anomaly scores on held-out sample ---
with torch.no_grad():
    test_shifted_tensor = torch.from_numpy(SR_test_shifted.astype("float32")).to(device)
    sig_log_prob = model_S.log_prob(
        inputs=test_shifted_tensor[:, 1:-1],
        context=test_shifted_tensor[:, 0:1],
    ).cpu().numpy()

sig_prob = np.exp(sig_log_prob)
bg_prob = np.exp(log_B_test.flatten()) * mass_pdf_test
ratio = sig_prob / (bg_prob + 1e-12)

labels = SR_test[:, -1]

plt.figure(figsize=(7, 4))
plt.hist(ratio[labels == 0], bins=40, density=True, histtype='step', linewidth=2, color='tab:blue', label='Background')
plt.hist(ratio[labels == 1], bins=40, density=True, histtype='stepfilled', alpha=0.4, color='tab:orange', label='Signal')
plt.yscale("log")
plt.xlabel("R(x) = p_sig / p_bg")
plt.ylabel("Density")
plt.legend()
plt.title("Residual ANODE Anomaly Score")
plt.show()

signal_eff = (ratio[labels == 1] > 1.0).mean()
background_eff = (ratio[labels == 0] > 1.0).mean()
print(f"Signal efficiency at R>1: {signal_eff:.3f}")
print(f"Background efficiency at R>1: {background_eff:.3f}")
# Out:
# Signal efficiency at R>1: 1.000
# Background efficiency at R>1: 1.000

# %%
# --- visualize strains vs time and distributions for data vs learned models ---
def sample_subset(data: np.ndarray, max_points: int = 600, rng: np.random.Generator = np.random.default_rng()):
    if len(data) <= max_points:
        return data
    idx = rng.choice(len(data), size=max_points, replace=False)
    return data[idx]

with torch.no_grad():
    cond_inputs = torch.from_numpy(SR_bkg_aligned_raw[:, 0].astype("float32")).reshape(-1, 1).to(device)
    bg_generated = model_B.model.sample(num_samples=cond_inputs.shape[0], cond_inputs=cond_inputs).cpu().numpy()
    sig_context = torch.from_numpy(SR_sig_shifted[:, 0:1].astype("float32")).to(device)
    generated = []
    for ctx in torch.split(sig_context, 1, dim=0):
        sample = model_S.sample(num_samples=1, context=ctx).cpu().numpy()
        if sample.ndim == 3:
            sample = sample[0, 0]
        elif sample.ndim == 2:
            sample = sample[0]
        generated.append(np.asarray(sample))
    sig_generated_features = np.stack(generated, axis=0)

bg_generated_full = np.concatenate([SR_bkg_aligned_raw[:, 0:1], bg_generated, np.zeros((bg_generated.shape[0], 1))], axis=1)
bg_generated_raw = inverse_transform(bg_generated_full, pre_params)

sig_time = sig_context.cpu().numpy() + center_time
sig_generated_features = np.atleast_2d(sig_generated_features)
sig_generated_processed = np.concatenate([sig_time, sig_generated_features, np.ones((sig_generated_features.shape[0], 1))], axis=1)
sig_generated_raw = inverse_transform(sig_generated_processed, pre_params)

plot_sets = {
    "Background Data": SR_bkg_aligned_raw,
    "Signal Data": SR_sig_aligned_raw,
    "Background Model": bg_generated_raw,
    "Signal Model": sig_generated_raw,
}

feature_names = [
    ("H_strain", 1),
    ("L_strain", 2),
    ("H+L", 3),
    ("H-L", 4),
 ]

rng = np.random.default_rng(2025)
for name, idx in feature_names:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    all_values = []
    for label, dataset in plot_sets.items():
        all_values.append(dataset[:, idx])
        subset = sample_subset(dataset, max_points=600, rng=rng)
        axes[0].scatter(subset[:, 0], subset[:, idx], label=label, s=10, alpha=0.5)
    axes[0].set_xlabel("Time [ms]")
    axes[0].set_ylabel(name)
    axes[0].set_title(f"{name} vs Time")
    axes[0].legend()

    values_concat = np.concatenate(all_values)
    vmin = np.quantile(values_concat, 0.01)
    vmax = np.quantile(values_concat, 0.99)
    bins = np.linspace(vmin, vmax, 60)

    for label, dataset in plot_sets.items():
        axes[1].hist(dataset[:, idx], bins=bins, histtype="step", density=True, label=label)

    axes[1].set_xlabel(name)
    axes[1].set_ylabel("Density")
    axes[1].set_title(f"{name} Distribution")
    axes[1].legend()
    plt.tight_layout()
    plt.show()
